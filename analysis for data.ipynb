# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.stats import randint

# %%
df=pd.read_csv(r"C:\Users\otaku7\Desktop\GP\clean_data.csv")
df.head()
# Out:
#    Age  Gender  self_employed  family_history  treatment  work_interfere  \
# 0   19       0              0               0          1               2
# 1   26       1              0               0          0               3
# 2   14       1              0               0          0               3
# 3   13       1              0               1          1               2
# 4   13       1              0               0          0               1
#
#    no_employees  remote_work  tech_company  benefits  ...  leave  \
# 0             4            0             1         2  ...      2
# 1             5            0             0         0  ...      0
# 2             4            0             1         1  ...      1
# 3             2            0             1         1  ...      1
# 4             1            1             1         2  ...      0
#
#    mental_health_consequence  phys_health_consequence  coworkers  supervisor  \
# ...

# %%
#correlation matrix
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);
plt.show()

# %% [markdown]
# # treatment correlation matrix

# %%
k = 11
cols = corrmat.nlargest(k, 'treatment')['treatment'].index
# np.corrcoef to compute the correlation coefficients between these columns.
corrm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.5)
hm = sns.heatmap(corrm, cbar=True, annot=True, square=True, fmt='.2f',
                 annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
# treatment and age
ta = sns.FacetGrid(df, col='treatment', size=5)
ta= ta.map(sns.distplot, "Age")
# Out:
# C:\Users\otaku7\anaconda3\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# C:\Users\otaku7\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\otaku7\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))

# Create a countplot of the "treatment" variable
g = sns.countplot(x="treatment", data=df)

# Set the x-axis tick labels to "Male" and "Female"
g.set_xticklabels([ "Female","Male"])



plt.show()
